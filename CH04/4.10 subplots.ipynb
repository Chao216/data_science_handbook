# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use("classic")

# %%
#plt.axes

ax1 = plt.axes() # fefault origin 
ax2 = plt.axes((0.65,0.65,0.2, 0.2)) # x, y 0.65 from origin respectivly, new plot width, height 20% to origin
ax3 = plt.axes((0.2,0.2,0.3,0.3)) # x,y 0.2 from origin respectivly, new plot weidth, hieght, 30% to default

# %%
# plt.GridSpec

grid = plt.GridSpec(3,3)

plt.subplot(grid[0,0])
plt.subplot(grid[0,1:])
plt.subplot(grid[1,:3])
plt.subplot(grid[2,:2])
plt.subplot(grid[2,2:])
# Out:
# <AxesSubplot:>
